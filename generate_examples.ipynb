# %%
import torch
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

model= torch.load('./results/coco/checkpoint_epoch_10.pth.tar')['model']

def show_and_tell(filename, beam_size=3):
    img = Image.open(filename, 'r')
    # %matplotlib inline
    imshow(np.asarray(img))
    captions = model.generate(img, beam_size=beam_size)
    print(captions)

# %%
show_and_tell('./COCO_val2014_000000000073.jpg')
# Out:
# ['a motorcycle parked on the side of a road. EOS', 'a motorcycle parked on the side of a road EOS', 'a motorcycle parked in a parking lot next to a building. EOS']

# %%
show_and_tell('./COCO_val2014_000000000285.jpg')
# Out:
# ['a black bear is standing in the grass. EOS', 'a black bear is standing in the middle of a field. EOS', 'a black bear is standing in the middle of a field EOS']
